# %% [markdown]
# <a href="https://www.analytiksinc.com">![ANALYTIKS_LOGO_FINAL-01.jpg](attachment:ANALYTIKS_LOGO_FINAL-01.jpg)</a>
# <p style="text-align: right;"> © 2020. Analytiks Inc. </p>

# %% [markdown]
# # Exercise: Working with APIs

# %% [markdown]
# _________

# %% [markdown]
# ## 1. Retrieving JSON from a  Quandl API
# ##### Retrieve a table showing Firms Not Needing a Loan in the Philippines for all dates surveyed from the World Bank Enterprise Survey on Quandl

# %% [markdown]
# 1. Sign up for a free Quandl account (https://www.quandl.com/sign-up)
# 2. Retrieve your API key and keep it accessible (https://help.quandl.com/article/320-where-can-i-find-my-api-key)
#
#
# <i/> Choose 'For Personal Use'

# %% [markdown]
# #### a. Import the Libraries

# %%
import requests
import pandas as pd
import numpy as np
import quandl

# %% [markdown]
# #### b. Setup your Quandl API Key

# %%
creds = pd.read_json('../Resources/quandl_creds.json', typ='series')
key = creds['api_key']

quandl.ApiConfig.api_key = key

# %% [markdown]
# #### c. Use the Quandl API to get the data as a JSON

# %%
request = requests.get('https://www.quandl.com/api/v3/datasets/WESV/PHL_IC_FRM_FIN_FIN20.json')

# %%
request
# Out:
# <Response [200]>

# %% [markdown]
# #### d. Inspect the retrieved data

# %%
loan = request.json()
loan
# Out:
# {'dataset': {'id': 21932153,
#   'dataset_code': 'PHL_IC_FRM_FIN_FIN20',
#   'database_code': 'WESV',
#   'name': 'Percent of firms not needing a loan - Philippines',
#   'description': 'Percent of firms not needing a loan - Philippines. ',
#   'refreshed_at': '2020-04-24T08:53:22.576Z',
#   'newest_available_date': '2015-12-31',
#   'oldest_available_date': '2009-12-31',
#   'column_names': ['Date', 'Value'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2009-12-31',
#   'end_date': '2015-12-31',
#   'data': [['2015-12-31', 68.9], ['2009-12-31', 56.0]],
#   'collapse': None,
#   'order': None,
#   'database_id': 13547}}

# %% [markdown]
# #### e. Place the results in a Dataframe and show the dataframe
# <i/> Hint: Setup columns and rows first

# %%
loan_dataset = loan['dataset']
df_loan = pd.DataFrame(loan_dataset['data'], columns = loan_dataset['column_names'])
df_loan.set_index('Date')
# Out:
#             Value
# Date
# 2015-12-31   68.9
# 2009-12-31   56.0

# %% [markdown]
# ___

# %% [markdown]
# ## 2. Retrieving data from Quandl using the Quandl Python Library
# ##### Retrieve a table showing Eggplant Production in the Philippines from 2010 onwards using the UN Food and Agriculture Data Product on Quandl

# %% [markdown]
# 1. Sign up for a free Quandl account (https://www.quandl.com/sign-up)
# 2. Retrieve your API key and keep it accessible (https://help.quandl.com/article/320-where-can-i-find-my-api-key)
#
#
# <i/> Choose 'For Personal Use'

# %% [markdown]
# #### a. Import the Libraries

# %%
import quandl

# %% [markdown]
# #### b. Setup your Quandl API Key

# %%
quandl.ApiConfig.api_key = key

# %% [markdown]
# #### c. Use the get function in the quandl python API documentation to retrieve the dataframe

# %%
data = quandl.get('UFAO/CR_AUBG_PHL')
data
# Out:
#             Area harvested - ha  Yield - hg/ha  Production - tonnes
# Date
# 1961-12-31              23000.0        20000.0              46000.0
# 1962-12-31              23000.0        23913.0              55000.0
# 1963-12-31              19700.0        24264.0              47800.0
# 1964-12-31              18020.0        24547.0              44234.0
# 1965-12-31              16520.0        28291.0              46737.0
# 1966-12-31              17520.0        29596.0              51852.0
# 1967-12-31              17440.0        30853.0              53808.0
# 1968-12-31              17070.0        36666.0              62589.0
# 1969-12-31              17450.0        33806.0              58991.0
# 1970-12-31              17680.0        38800.0              68599.0
# 1971-12-31              15780.0        40342.0              63659.0
# 1972-12-31              19100.0        33928.0              64802.0
# 1973-12-31              19290.0        41160.0              79398.0
# 1974-12-31              17140.0        51865.0              88897.0
# 1975-12-31              16820.0        49551.0              83345.0
# 1976-12-31              16220.0        50785.0              82374.0
# 1977-12-31              16830.0        51620.0              86876.0
# 1978-12-31              17180.0        53722.0              92295.0
# 1979-12-31              16970.0        61268.0             103971.0
# 1980-12-31              17230.0        64370.0             110910.0
# 1981-12-31              15530.0        77640.0             120575.0
# 1982-12-31              14770.0        85010.0             125560.0
# 1983-12-31              14243.0        78679.0             112063.0
# 1984-12-31              14693.0        75109.0             110358.0
# 1985-12-31              14396.0        71321.0             102673.0
# 1986-12-31              14478.0        72212.0             104548.0
# 1987-12-31              14793.0        72785.0             107671.0
# 1988-12-31              15275.0        71883.0             109802.0
# 1989-12-31              16725.0        66713.0             111578.0
# 1990-12-31              16425.0        68617.0             112704.0
# 1991-12-31              14465.0        71925.0             104040.0
# 1992-12-31              15535.0        71098.0             110451.0
# 1993-12-31              17416.0        64120.0             111672.0
# 1994-12-31              17762.0        69514.0             123471.0
# 1995-12-31              17643.0        74082.0             130702.0
# 1996-12-31              18074.0        87199.0             157603.0
# 1997-12-31              18954.0       102898.0             195032.0
# 1998-12-31              16102.0       101747.0             163833.0
# 1999-12-31              19386.0        82402.0             159744.0
# 2000-12-31              19949.0        83285.0             166146.0
# 2001-12-31              20422.0        83155.0             169819.0
# 2002-12-31              20813.0        86321.0             179659.0
# 2003-12-31              20984.0        84346.0             176991.0
# 2004-12-31              21068.0        86744.0             182753.0
# 2005-12-31              21233.0        88444.0             187793.0
# 2006-12-31              20901.0        91819.0             191911.0
# 2007-12-31              21613.0        97236.0             210156.0
# 2008-12-31              21299.0        93703.0             199579.0
# 2009-12-31              21170.0        94918.0             200942.0
# 2010-12-31              21423.0        97205.0             208242.0
# 2011-12-31              21377.0        97298.0             207994.0
# 2012-12-31              21485.0        98620.0             211885.0
# 2013-12-31              21239.0       103541.0             219911.0
# 2014-12-31              21159.0       106611.0             225579.0
# 2015-12-31              21008.0       110845.0             232864.0
# 2016-12-31              21038.0       111999.0             235626.0
# 2017-12-31              21446.0       112798.0             241901.0
# 2018-12-31              21651.0       113083.0             244838.0

# %% [markdown]
# #### d. Filter for the said years

# %%
eggplant = data.reset_index()
eggplant
# Out:
#          Date  Area harvested - ha  Yield - hg/ha  Production - tonnes
# 0  1961-12-31              23000.0        20000.0              46000.0
# 1  1962-12-31              23000.0        23913.0              55000.0
# 2  1963-12-31              19700.0        24264.0              47800.0
# 3  1964-12-31              18020.0        24547.0              44234.0
# 4  1965-12-31              16520.0        28291.0              46737.0
# 5  1966-12-31              17520.0        29596.0              51852.0
# 6  1967-12-31              17440.0        30853.0              53808.0
# 7  1968-12-31              17070.0        36666.0              62589.0
# 8  1969-12-31              17450.0        33806.0              58991.0
# 9  1970-12-31              17680.0        38800.0              68599.0
# 10 1971-12-31              15780.0        40342.0              63659.0
# 11 1972-12-31              19100.0        33928.0              64802.0
# 12 1973-12-31              19290.0        41160.0              79398.0
# 13 1974-12-31              17140.0        51865.0              88897.0
# 14 1975-12-31              16820.0        49551.0              83345.0
# 15 1976-12-31              16220.0        50785.0              82374.0
# 16 1977-12-31              16830.0        51620.0              86876.0
# 17 1978-12-31              17180.0        53722.0              92295.0
# 18 1979-12-31              16970.0        61268.0             103971.0
# 19 1980-12-31              17230.0        64370.0             110910.0
# 20 1981-12-31              15530.0        77640.0             120575.0
# 21 1982-12-31              14770.0        85010.0             125560.0
# 22 1983-12-31              14243.0        78679.0             112063.0
# 23 1984-12-31              14693.0        75109.0             110358.0
# 24 1985-12-31              14396.0        71321.0             102673.0
# 25 1986-12-31              14478.0        72212.0             104548.0
# 26 1987-12-31              14793.0        72785.0             107671.0
# 27 1988-12-31              15275.0        71883.0             109802.0
# 28 1989-12-31              16725.0        66713.0             111578.0
# 29 1990-12-31              16425.0        68617.0             112704.0
# 30 1991-12-31              14465.0        71925.0             104040.0
# 31 1992-12-31              15535.0        71098.0             110451.0
# 32 1993-12-31              17416.0        64120.0             111672.0
# 33 1994-12-31              17762.0        69514.0             123471.0
# 34 1995-12-31              17643.0        74082.0             130702.0
# 35 1996-12-31              18074.0        87199.0             157603.0
# 36 1997-12-31              18954.0       102898.0             195032.0
# 37 1998-12-31              16102.0       101747.0             163833.0
# 38 1999-12-31              19386.0        82402.0             159744.0
# 39 2000-12-31              19949.0        83285.0             166146.0
# 40 2001-12-31              20422.0        83155.0             169819.0
# 41 2002-12-31              20813.0        86321.0             179659.0
# 42 2003-12-31              20984.0        84346.0             176991.0
# 43 2004-12-31              21068.0        86744.0             182753.0
# 44 2005-12-31              21233.0        88444.0             187793.0
# 45 2006-12-31              20901.0        91819.0             191911.0
# 46 2007-12-31              21613.0        97236.0             210156.0
# 47 2008-12-31              21299.0        93703.0             199579.0
# 48 2009-12-31              21170.0        94918.0             200942.0
# 49 2010-12-31              21423.0        97205.0             208242.0
# 50 2011-12-31              21377.0        97298.0             207994.0
# 51 2012-12-31              21485.0        98620.0             211885.0
# 52 2013-12-31              21239.0       103541.0             219911.0
# 53 2014-12-31              21159.0       106611.0             225579.0
# 54 2015-12-31              21008.0       110845.0             232864.0
# 55 2016-12-31              21038.0       111999.0             235626.0
# 56 2017-12-31              21446.0       112798.0             241901.0
# 57 2018-12-31              21651.0       113083.0             244838.0

# %%
eggplant[eggplant['Date'].dt.year >= 2010].set_index('Date')
# Out:
#             Area harvested - ha  Yield - hg/ha  Production - tonnes
# Date
# 2010-12-31              21423.0        97205.0             208242.0
# 2011-12-31              21377.0        97298.0             207994.0
# 2012-12-31              21485.0        98620.0             211885.0
# 2013-12-31              21239.0       103541.0             219911.0
# 2014-12-31              21159.0       106611.0             225579.0
# 2015-12-31              21008.0       110845.0             232864.0
# 2016-12-31              21038.0       111999.0             235626.0
# 2017-12-31              21446.0       112798.0             241901.0
# 2018-12-31              21651.0       113083.0             244838.0

# %% [markdown]
# _________

# %% [markdown]
# ## 3. Retrieving Browsers Used to Access <a href='https://www.data.gov/'>Data.gov </a>
# ##### Retrieve the list of browsers on Data.gov using this request
#
# <a href="https://analytics.usa.gov/data/live/browsers.json"> https://analytics.usa.gov/data/live/browsers.json </a>

# %% [markdown]
# #### 1. Import libraries

# %%
import requests

# %% [markdown]
# #### 2. Request for the data

# %%
response = requests.get('https://analytics.usa.gov/data/live/browsers.json')
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 3. Print out the results in raw form

# %%
data2 = response.json()
data2
# Out:
# {'name': 'browsers',
#  'sampling': {'containsSampledData': False},
#  'query': {'start-date': '90daysAgo',
#   'end-date': 'yesterday',
#   'dimensions': 'ga:date,ga:browser',
#   'metrics': ['ga:sessions'],
#   'sort': ['ga:date', '-ga:sessions'],
#   'filters': 'ga:sessions>10',
#   'start-index': 1,
#   'max-results': 10000,
#   'samplingLevel': 'HIGHER_PRECISION'},
#  'meta': {'name': 'Browsers',
#   'description': '90 days of visits broken down by browser for all sites. (>100 sessions)'},
#  'totals': {'visits': 4836478291,
#   'browser': {'Chrome': 2310647276,
#    'Safari': 1694664472,
#    'Edge': 199346714,
#    'Internet Explorer': 180553037,
#    'Firefox': 159121768,
#    'Samsung Internet': 139663951,
#    'Safari (in-app)': 62967000,
#    'Android Webview': 49978134,
#    'Amazon Silk': 10784732,
#    'Opera': 12734876,
#    'Mercari_d': 4775225,
#    'UC Browser': 2454267,
#    'Opera Mini': 1825502,
#    'Mozilla Compatible Agent': 1397538,
#    'YaBrowser': 1104335,
#    'Coc Coc': 454346,
#    'DoximityWebView': 89848,
#    'Android Browser': 493218,
#    'ELB-HealthChecker': 557148,
#    'Amazon.com': 307947,
#    'Playstation 4': 176404,
#    'Puffin': 171390,
#    'BestBuy': 131496,
#    'Mozilla': 144119,
#    'ThousandEyes': 164525,
#    'SeaMonkey': 121790,
#    'UA-name:iOSDasherWebView; client-version: 2.58.0.2156.200425': 5752,
#    'ulta-app-ios': 37497,
#    'BlackBerry': 79617,
#    'BublupBot': 48859,
#    'Maxthon': 50826,
#    'United States Postal Service - TRG19-01Loeim': 58872,
#    'IRS - TRG19-01Loeim': 58920,
#    'com.doximity.doximitydroid': 9768,
#    'Instagram 139.1.0.39.120': 2778,
#    'Iron': 29974,
#    'Voxgov': 39500,
#    'Android Runtime': 42812,
#    'Airbnb': 22315,
#    'Papers': 36166,
#    'com.airfind.deltabrowser': 15109,
#    'MagentaNews': 28253,
#    '[FBAN': 27787,
#    '(not set)': 20693,
#    'Bluebeam Revu Browser - cef version: 57.0.0.0': 11428,
#    'candroid': 16806,
#    'Netscape': 18227,
#    'Instagram 130.0.0.15.120': 2467,
#    'Android': 57122,
#    'mediacloud bot for open academic research': 2079,
#    'iPhone': 47086,
#    'Carousel': 16796,
#    'Instagram 140.0.0.25.126': 7684,
#    'Playstation 3': 10105,
#    'UA-name:iOSDasherWebView; client-version: 2.56.0.1918.200416': 707,
#    'Microsoft Office Word 2014': 12305,
#    'ulta-app-android': 9330,
#    'Lore Document Collector 5a20b182ca368a24e6462a7ac6947051': 6329,
#    'WordPress': 11460,
#    'Handshake iOS 2.2.4': 1104,
#    'Windows NT 6.1': 3847,
#    'Nintendo Browser': 12604,
#    'LeapPadUltimate': 7776,
#    'MRCHROME': 7327,
#    'ZhihuHybrid DefaultBrowser osee2unifiedRelease': 8859,
#    'Hexometer': 6294,
#    'Google-Test2': 7117,
#    'lua-resty-http': 8319,
#    'success agent': 4737,
#    'Seznam': 6157,
#    '"Mozilla': 3813,
#    'Playstation Vita Browser': 3984,
#    'NetFront': 3170,
#    'Microsoft Office Excel 2014': 3062,
#    'LeapPad3Explorer': 2092,
#    'Mobile IOS 9.2.2.1; Mozilla': 1932,
#    'Emb': 10405,
#    'Uzbl': 2444,
#    'eQAfy_Website_Checker_Bot_https:': 465,
#    'HubSpot-Link-Resolver': 120,
#    'NinjBot': 353,
#    'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.7.0': 31,
#    'Instagram 101.0.0.12.119': 29,
#    '172.18.13.10:9092': 5634,
#    'IE with Chrome Frame': 1035,
#    'LeapPadPlatinum': 2011,
#    'Mobile IOS 4.0.0.11; Mozilla': 49,
#    'InDesign': 41,
#    'DDG-Android-3.1.0': 1799,
#    'Nokia Browser': 1563,
#    'DingTalkBot-LinkService': 1488,
#    'NerdWallet': 2824,
#    'Nintendo 3DS Browser': 1173,
#    'WizenozeBot': 5658,
#    'Grammarly': 357,
#    'Instagram 138.0.0.32.117': 256,
#    'com.airfind.browser': 417,
#    '+Simple Browser': 1686,
#    'LiveSlides': 604,
#    'pa11y': 4554,
#    'LINER': 632,
#    'Jetty': 2226,
#    'Rely Bot': 4695,
#    'Welltory': 560,
#    'HCL Verse': 14,
#    'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.7.0': 14,
#    'Instagram 132.1.0.21.129': 846,
#    'PolycomVVX Lync': 1750,
#    'qbhttp': 80,
#    'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.8.0': 397,
#    'Instagram 139.0.0.33.121 Android': 30,
#    'Lunascape': 1398,
#    'https:': 74,
#    'mozilla': 502,
#    'Ruby': 54,
#    'Tracker': 948,
#    'chrome-Selenium': 1678,
#    'neoload': 431,
#    'android': 340,
#    'UA-name:iOSDasherWebView; client-version: 2.54.2.1852.200411': 35,
#    'Microsoft Office Word 2013': 666,
#    'Microsoft Office Excel 2013': 228,
#    'UCWEB': 15,
#    'osee2unifiedRelease': 388,
#    'class s extends Function{constructor': 377,
#    'Nokia6280': 893,
#    'WebsiteScreenshotCreator': 77,
#    'Outlook-iOS': 629,
#    'TravelSmart': 241,
#    'Instagram 126.0.0.13.120': 1204,
#    'Instagram 135.1.0.23.118': 82,
#    'Instagram 123.1.0.26.115': 1419,
#    'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.8.0': 272,
#    'bitdiscovery': 42575,
#    'AndroidDownloadManager': 304,
#    'Camino': 112,
#    'Bloomberg|iOS|13.3.1|5.20.0|b18ca9dd5d1b86c08b1bae0c6e3774aa77ef49aa': 14,
#    'Venmo': 142,
#    'QuickTime': 26,
#    'com.seekingalpha.webwrapper': 118,
#    'YE': 216,
#    'UA-name:iOSDasherWebView; client-version: 2.60.0.2321.200501': 15940,
#    'WordPress.com; https:': 245,
#    'http.rb': 89,
#    'UA-name:iOSDasherWebView; client-version: 2.52.1.1438.200320': 14,
#    'Browser': 35,
#    'media-bot': 60,
#    'BreitbartApp': 46,
#    'Lore Document Collector 1bb1dbb613d0db2041e35f52fea672c7': 227,
#    'AppleCoreMedia': 535,
#    'Lynx': 417,
#    'Instagram 141.0.0.24.117': 5118,
#    '192.168.25.97:9092': 1330,
#    'Instagram 140.0.0.30.126 Android': 42,
#    'Nexgate Ruby Client': 226,
#    'Web App': 13,
#    'Selenium': 212,
#    'Coursera-Mobile 3.7.2': 11,
#    'Konqueror': 11,
#    'Microsoft.Data.Mashup': 11,
#    'Instagram 120.0.0.18.116': 772,
#    'Handshake iOS 2.2.5': 2078,
#    'Microsoft Office PowerPoint 2014': 192,
#    'Netsparker Agent': 111,
#    'Bloomberg|iOS|13.4.1|5.21.0|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 296,
#    'PostmanRuntime': 166,
#    'iTunes': 220,
#    'Podcasts': 95,
#    'mofang_app': 12,
#    'Bloomberg|iOS|13.3.1|5.21.0|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 35,
#    'screeenly-bot 2.0': 72,
#    'Instagram 136.0.0.22.123': 1548,
#    'Bloomberg|Android|10|5.21.0.2276979.d5d05c178|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 27,
#    'Docoloc': 22,
#    'Ephox': 11,
#    'Instagram 137.0.0.30.124': 601,
#    'Instagram 133.0.0.20.118': 1324,
#    'newsmthApp': 13,
#    'CareDroidMedications': 23,
#    'HRB-MOBILE-IOS-PHONE-TAXES-9.8.0': 57,
#    'Booking.com Android App 22.3.1': 203,
#    'fuelbot': 37,
#    'NewsSlide': 17,
#    'RiteAidMobile': 66,
#    'Coursera-Mobile 3.8.1': 193,
#    'Phantom.js bot': 464,
#    'UA-name:iOSDasherWebView; client-version: 2.62.0.2524.200508': 4049,
#    'Grailed': 34,
#    'Mobile IOS 9.2.3.1; Mozilla': 351,
#    'Booking.App': 7400,
#    '192.168.0.18': 19,
#    'NE3': 517,
#    'Instagram 142.0.0.22.109': 8401,
#    'HV Android Wrapper 0.1': 11,
#    'Screaming Frog SEO Spider': 889,
#    'UA-name:iOSDasherWebView; client-version: 2.62.20.2760.200519': 10593,
#    'UNL_SITEMASTER': 288,
#    'iMozilla': 69,
#    'Manticore 0.6.4': 52,
#    'freeweb2app': 27,
#    'Ocean': 21,
#    'Instagram 123.0.0.24.115': 230,
#    'Infowars Android': 460,
#    'Sogou web spider': 13,
#    'iPad': 354,
#    'colly - https:': 124,
#    'GeenStijlAndroidApp': 26,
#    'Handshake iOS 2.3.0': 171,
#    'SpeedaNewsPicks': 129,
#    'Watchville Android 1.5.2': 28,
#    'EPiServer LinkValidator': 14,
#    'Handshake iOS 2.3.1': 1492,
#    'WAS': 56,
#    'CastBox': 43,
#    'Instagram 143.0.0.20.122': 6349,
#    'blackboard ally - accessibility checker - http:': 34,
#    'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.9.0': 1707,
#    'lyft:android:9:6.33.3.1590119151': 1942,
#    'bma': 11,
#    'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.9.0': 779,
#    'com.tophatter v2.103.7': 3853,
#    'Instagram 132.0.0.18.129': 1036,
#    'com.tophatter v3.0.0': 16486,
#    'com.tophatter v2.103.10': 768,
#    'lyft:android:10:6.33.3.1590119151': 832,
#    'sdfsdf': 404,
#    'lyft:android:8.1.0:6.33.3.1590119151': 381,
#    'com.tophatter v2.103.5': 278,
#    'lyft:android:8.0.0:6.33.3.1590119151': 141,
#    'com.tophatter v2.103.6': 187,
#    'com.lyft.android.driver:android:9:1002.62.3.1590119153': 57,
#    'lyft:android:7.0:6.33.3.1590119151': 69,
#    '7Siters': 11,
#    'lyft:android:9:6.34.3.1590583701': 7948,
#    'Instagram 144.0.0.17.119': 4572,
#    'com.tophatter v2.101.1': 120,
#    'curb': 14,
#    'broken-link-checker': 12,
#    'spyglassbot puppeteer': 52,
#    'UA-name:iOSDasherWebView; client-version: 2.64.0.2878.200522': 3545,
#    'UA-name:iOSDasherWebView; client-version: 2.68.0.3047.200529': 20777,
#    'Microsoft Office PowerPoint 2013': 15,
#    'lyft:android:10:6.34.3.1590583701': 4895,
#    'Bloomberg|iOS|13.4.1|5.22.1|9711b09eb675cf0e3556545cbd97f1441e374cf6': 13,
#    'com.tophatter v2.100.0': 33,
#    'com.tophatter v4.0.1': 520,
#    'lyft:android:8.1.0:6.34.3.1590583701': 1759,
#    'win10chrome76': 13,
#    'lyft:android:8.0.0:6.34.3.1590583701': 919,
#    'PipelinePilot': 11,
#    'lyft:android:7.0:6.34.3.1590583701': 640,
#    'com.tophatter v4.0.3': 194,
#    'eXtyles WinINet 1.0': 17,
#    'Handshake iOS 2.3.2': 933,
#    'Citoid': 13,
#    'com.lyft.android.driver:android:10:1002.63.3.1590584246': 262,
#    'Opendi Screenshot Bot bot@opendi.com': 135110,
#    'com.lyft.android.driver:android:9:1002.63.3.1590584246': 300,
#    'lyft:android:7.1.1:6.34.3.1590583701': 224,
#    'lyft:android:9:6.35.3.1591222463': 8583,
#    'Instagram 145.0.0.17.119': 4274,
#    'lyft:android:6.0.1:6.34.3.1590583701': 166,
#    'com.lyft.android.driver:android:8.1.0:1002.63.3.1590584246': 54,
#    'lyft:android:10:6.35.3.1591222463': 6391,
#    'com.lyft.android.driver:android:8.0.0:1002.63.3.1590584246': 37,
#    'lyft:android:7.1.2:6.34.3.1590583701': 37,
#    'com.lyft.android.driver:android:9:1002.64.3.1591188541': 405,
#    'com.lyft.android.driver:android:7.0:1002.63.3.1590584246': 16,
#    'Bloomberg|iOS|13.4.1|5.23.0|d63663da08e3ad75571d9550d5fd685884e03392': 41,
#    'lyft:android:8.1.0:6.35.3.1591222463': 1858,
#    'com.tophatter v4.0.4': 225,
#    'WebKit': 12,
#    'com.lyft.android.driver:android:10:1002.62.3.1590119153': 12,
#    'com.lyft.android.driver:android:10:1002.64.3.1591188541': 399,
#    'lyft:android:8.0.0:6.35.3.1591222463': 1173,
#    'lyft:android:7.0:6.35.3.1591222463': 780,
#    'integrity': 26,
#    'lyft:android:6.0.1:6.35.3.1591222463': 176,
#    'UA-name:iOSDasherWebView; client-version: 2.70.1.3286.200610': 928,
#    'lyft:android:7.1.1:6.35.3.1591222463': 251,
#    'HRB-MOBILE-IOS-PHONE-TAXES-9.9.0': 347,
#    'UA-name:iOSDasherWebView; client-version: 2.70.2.3352.200612': 17426,
#    'Papers2 Thumbnail Helper': 41,
#    'Downcast': 13,
#    'liloiosapp-66.1.6 Mozilla': 37,
#    'com.lyft.android.driver:android:8.0.0:1002.64.3.1591188541': 11,
#    'lyft:android:7.1.2:6.35.3.1591222463': 22,
#    'Instagram 115.1.0.71.189': 1030,
#    'hogehoge': 126,
#    'Turnitin': 7143,
#    'CourierAndroid 5.22.2 rv:434': 12,
#    'Rustbot': 314,
#    'Drupal': 13,
#    'newspaper': 81,
#    'lyft:android:9:6.36.3.1591794132': 6780,
#    'Instagram 145.0.0.32.119 Android': 27,
#    'lyft:android:10:6.36.3.1591794132': 5638,
#    'com.lyft.android.driver:android:8.1.0:1002.64.3.1591188541': 11,
#    'UA-name:iOSDasherWebView; client-version: 2.72.0.3380.200612': 22309,
#    'Handshake iOS 2.3.3': 1193,
#    'lyft:android:8.1.0:6.36.3.1591794132': 1314,
#    'Yewno-Open': 17,
#    'lyft:android:7.0:6.36.3.1591794132': 568,
#    'lyft:android:8.0.0:6.36.3.1591794132': 1004,
#    'SalesforceMobileSDK': 18,
#    'com.lyft.android.driver:android:9:1002.65.3.1591791298': 289,
#    'com.lyft.android.driver:android:10:1002.65.3.1591791298': 321,
#    'lyft:android:7.1.1:6.36.3.1591794132': 190,
#    'Kronos': 11,
#    'lyft:android:6.0.1:6.36.3.1591794132': 143,
#    'Instagram 146.0.0.21.122': 6656,
#    'Instagram 124.0.0.11.473': 39,
#    'Party City Mobile App; iOS iPhone; 13.5.1; 6.1.16.0 : 48;': 11,
#    'EcoSearch': 18,
#    'PollEvPresenter': 40,
#    'com.lyft.android.driver:android:8.0.0:1002.65.3.1591791298': 22,
#    'Accessibility scan - NLM staff': 15945,
#    'Coursera-Mobile 3.9.1': 99,
#    'lyft:android:9:6.37.3.1592395944': 5405,
#    'Instagram 139.0.0.34.120': 528,
#    'ds9 2.004.1': 14,
#    'lyft:android:10:6.37.3.1592395944': 4794,
#    'UA-name:iOSDasherWebView; client-version: 2.74.0.1': 21891,
#    'Handshake iOS 2.3.4': 1898,
#    'lyft:android:8.1.0:6.37.3.1592395944': 1028,
#    'lyft:android:8.0.0:6.37.3.1592395944': 775,
#    'SearchBlox': 42,
#    'Asana': 93,
#    'lyft:android:7.0:6.37.3.1592395944': 470,
#    'com.lyft.android.driver:android:9:1002.66.3.1592396259': 240,
#    'com.lyft.android.driver:android:10:1002.66.3.1592396259': 253,
#    'Instagram 147.0.0.30.121': 5256,
#    'lyft:android:7.1.1:6.37.3.1592395944': 142,
#    'lyft:android:6.0.1:6.37.3.1592395944': 90,
#    'RANDOM': 47,
#    'TotalValidator': 31,
#    'Instagram 147.0.0.42.124 Android': 82,
#    'edbrowse': 240,
#    'ADPTablet': 361,
#    'lyft:android:9:6.38.3.1593001991': 8503,
#    'lyft:android:10:6.38.3.1593001991': 8559,
#    'UA-name:iOSDasherWebView; client-version: 2.76.0.3489.200626': 27191,
#    'lyft:android:8.1.0:6.38.3.1593001991': 1661,
#    'Bloomberg|iOS|13.5.1|5.24.0|b954812d89433af9535e6ab38f9141628dc46e27': 86,
#    'lyft:android:8.0.0:6.38.3.1593001991': 1476,
#    'VSE': 12,
#    'Java': 100,
#    'lyft:android:7.0:6.38.3.1593001991': 773,
#    'lyft:android:6.0.1:6.38.3.1593001991': 153,
#    'lyft:android:7.1.1:6.38.3.1593001991': 280,
#    'Instagram 148.0.0.26.120': 14011,
#    'com.lyft.android.driver:android:10:1002.67.3.1593002387': 340,
#    'com.lyft.android.driver:android:9:1002.67.3.1593002387': 256,
#    'GreenChoiceNow': 11,
#    'Connie': 23,
#    'axios': 20,
#    'JovemNerdApp': 741,
#    'Bloomberg|iOS|13.5.1|5.25.0|688ee79ba47d67452eae5db8faede63e8ee6801d': 484,
#    'Bloomberg|Android|10|5.25.0.2358368.688ee79ba|688ee79ba47d67452eae5db8faede63e8ee6801d': 68,
#    'UA-name:iOSDasherWebView; client-version: 2.78.0.3587.200702': 31604,
#    'QZONEJSSDK': 27,
#    'HRB-MOBILE-IOS-TABLET-TAXES-TOUCHID-9.9.0': 218,
#    'Android ExpediaBookings': 14,
#    'Autn-WKOOP': 250,
#    'com.tophatter v5.0.1': 504,
#    'PodcastAddict': 11,
#    'desktop': 1040,
#    'Turo': 14,
#    'CBC': 664,
#    'cnn-mobile-app': 2542,
#    'HRB-MOBILE-IOS-TABLET-TAXES-9.9.0': 71,
#    'Instagram 131.0.0.21.117': 161,
#    'lyft:android:9:6.40.3.1594331922': 2906,
#    'lyft:android:10:6.40.3.1594331922': 3741,
#    'UA-name:iOSDasherWebView; client-version: 2.80.0.3681.200710': 9319,
#    'Lync': 35,
#    'lyft:android:8.1.0:6.40.3.1594331922': 586,
#    'lyft:android:8.0.0:6.40.3.1594331922': 578,
#    'HRB-MOBILE-IOS-TABLET-TAXES-FACEID-9.9.0': 26,
#    'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.9.0-Mozilla': 25,
#    'lyft:android:7.0:6.40.3.1594331922': 302,
#    '{user_agent}': 59,
#    'lyft:android:7.1.1:6.40.3.1594331922': 86,
#    'AtlassianMobileApp': 16,
#    'com.automizely.shopping': 16,
#    'com.lyft.android.driver:android:10:1002.69.3.1594209951': 142,
#    'com.lyft.android.driver:android:9:1002.69.3.1594209951': 47,
#    'lyft:android:6.0.1:6.40.3.1594331922': 71,
#    'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.10.0': 41,
#    'UA-name:iOSDasherWebView; client-version: 2.80.1.3740.200716': 11287,
#    'Instagram 150.0.0.22.119': 3977,
#    'AfricaWeb: GhanaWeb': 19,
#    'SCMGUARD': 26,
#    'Parler': 24,
#    'WayfairApp': 27,
#    'Bloomberg|iOS|13.5.1|5.26.0|0d2c9fc30a7d66305ef5ac5cbebf7cd19474e0b5': 92,
#    'lyft:android:9:6.41.3.1594814997': 1612,
#    'Handshake iOS 3.0.0': 339,
#    'lyft:android:10:6.41.3.1594814997': 2208,
#    'UA-name:iOSDasherWebView; client-version: 2.82.0.3756.200717': 10869,
#    'http4s-blaze': 21,
#    'lyft:android:8.0.0:6.41.3.1594814997': 256,
#    'lyft:android:8.1.0:6.41.3.1594814997': 232,
#    'Bloomberg|Android|10|5.26.0.2377502.0d2c9fc30|0d2c9fc30a7d66305ef5ac5cbebf7cd19474e0b5': 11,
#    'lyft:android:7.0:6.41.3.1594814997': 128,
#    'Instagram 129.0.0.19.117': 568,
#    'com.lyft.android.driver:android:10:1002.70.3.1595041156': 62,
#    'ShortLinkTranslate': 19,
#    'lyft:android:7.1.1:6.41.3.1594814997': 46,
#    'netdisk;2.2.2;pc;pc-mac;10.14.5;macbaiduyunguanjia': 13,
#    'lyft:android:6.0.1:6.41.3.1594814997': 23,
#    'com.lyft.android.driver:android:9:1002.70.3.1595041156': 13,
#    'Revolut': 22,
#    'browser1': 17}},
#  'taken_at': '2020-08-04T10:00:36.700Z'}

# %%
data2.keys()
# Out:
# dict_keys(['name', 'sampling', 'query', 'meta', 'totals', 'taken_at'])

# %%
data2['totals'].keys()
# Out:
# dict_keys(['visits', 'browser'])

# %% [markdown]
# #### 4. Print out the results as a dataframe
# <i/> Hint: use pandas from_dict method

# %%
brows = data2['totals']['browser']
brows
# Out:
# {'Chrome': 2310647276,
#  'Safari': 1694664472,
#  'Edge': 199346714,
#  'Internet Explorer': 180553037,
#  'Firefox': 159121768,
#  'Samsung Internet': 139663951,
#  'Safari (in-app)': 62967000,
#  'Android Webview': 49978134,
#  'Amazon Silk': 10784732,
#  'Opera': 12734876,
#  'Mercari_d': 4775225,
#  'UC Browser': 2454267,
#  'Opera Mini': 1825502,
#  'Mozilla Compatible Agent': 1397538,
#  'YaBrowser': 1104335,
#  'Coc Coc': 454346,
#  'DoximityWebView': 89848,
#  'Android Browser': 493218,
#  'ELB-HealthChecker': 557148,
#  'Amazon.com': 307947,
#  'Playstation 4': 176404,
#  'Puffin': 171390,
#  'BestBuy': 131496,
#  'Mozilla': 144119,
#  'ThousandEyes': 164525,
#  'SeaMonkey': 121790,
#  'UA-name:iOSDasherWebView; client-version: 2.58.0.2156.200425': 5752,
#  'ulta-app-ios': 37497,
#  'BlackBerry': 79617,
#  'BublupBot': 48859,
#  'Maxthon': 50826,
#  'United States Postal Service - TRG19-01Loeim': 58872,
#  'IRS - TRG19-01Loeim': 58920,
#  'com.doximity.doximitydroid': 9768,
#  'Instagram 139.1.0.39.120': 2778,
#  'Iron': 29974,
#  'Voxgov': 39500,
#  'Android Runtime': 42812,
#  'Airbnb': 22315,
#  'Papers': 36166,
#  'com.airfind.deltabrowser': 15109,
#  'MagentaNews': 28253,
#  '[FBAN': 27787,
#  '(not set)': 20693,
#  'Bluebeam Revu Browser - cef version: 57.0.0.0': 11428,
#  'candroid': 16806,
#  'Netscape': 18227,
#  'Instagram 130.0.0.15.120': 2467,
#  'Android': 57122,
#  'mediacloud bot for open academic research': 2079,
#  'iPhone': 47086,
#  'Carousel': 16796,
#  'Instagram 140.0.0.25.126': 7684,
#  'Playstation 3': 10105,
#  'UA-name:iOSDasherWebView; client-version: 2.56.0.1918.200416': 707,
#  'Microsoft Office Word 2014': 12305,
#  'ulta-app-android': 9330,
#  'Lore Document Collector 5a20b182ca368a24e6462a7ac6947051': 6329,
#  'WordPress': 11460,
#  'Handshake iOS 2.2.4': 1104,
#  'Windows NT 6.1': 3847,
#  'Nintendo Browser': 12604,
#  'LeapPadUltimate': 7776,
#  'MRCHROME': 7327,
#  'ZhihuHybrid DefaultBrowser osee2unifiedRelease': 8859,
#  'Hexometer': 6294,
#  'Google-Test2': 7117,
#  'lua-resty-http': 8319,
#  'success agent': 4737,
#  'Seznam': 6157,
#  '"Mozilla': 3813,
#  'Playstation Vita Browser': 3984,
#  'NetFront': 3170,
#  'Microsoft Office Excel 2014': 3062,
#  'LeapPad3Explorer': 2092,
#  'Mobile IOS 9.2.2.1; Mozilla': 1932,
#  'Emb': 10405,
#  'Uzbl': 2444,
#  'eQAfy_Website_Checker_Bot_https:': 465,
#  'HubSpot-Link-Resolver': 120,
#  'NinjBot': 353,
#  'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.7.0': 31,
#  'Instagram 101.0.0.12.119': 29,
#  '172.18.13.10:9092': 5634,
#  'IE with Chrome Frame': 1035,
#  'LeapPadPlatinum': 2011,
#  'Mobile IOS 4.0.0.11; Mozilla': 49,
#  'InDesign': 41,
#  'DDG-Android-3.1.0': 1799,
#  'Nokia Browser': 1563,
#  'DingTalkBot-LinkService': 1488,
#  'NerdWallet': 2824,
#  'Nintendo 3DS Browser': 1173,
#  'WizenozeBot': 5658,
#  'Grammarly': 357,
#  'Instagram 138.0.0.32.117': 256,
#  'com.airfind.browser': 417,
#  '+Simple Browser': 1686,
#  'LiveSlides': 604,
#  'pa11y': 4554,
#  'LINER': 632,
#  'Jetty': 2226,
#  'Rely Bot': 4695,
#  'Welltory': 560,
#  'HCL Verse': 14,
#  'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.7.0': 14,
#  'Instagram 132.1.0.21.129': 846,
#  'PolycomVVX Lync': 1750,
#  'qbhttp': 80,
#  'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.8.0': 397,
#  'Instagram 139.0.0.33.121 Android': 30,
#  'Lunascape': 1398,
#  'https:': 74,
#  'mozilla': 502,
#  'Ruby': 54,
#  'Tracker': 948,
#  'chrome-Selenium': 1678,
#  'neoload': 431,
#  'android': 340,
#  'UA-name:iOSDasherWebView; client-version: 2.54.2.1852.200411': 35,
#  'Microsoft Office Word 2013': 666,
#  'Microsoft Office Excel 2013': 228,
#  'UCWEB': 15,
#  'osee2unifiedRelease': 388,
#  'class s extends Function{constructor': 377,
#  'Nokia6280': 893,
#  'WebsiteScreenshotCreator': 77,
#  'Outlook-iOS': 629,
#  'TravelSmart': 241,
#  'Instagram 126.0.0.13.120': 1204,
#  'Instagram 135.1.0.23.118': 82,
#  'Instagram 123.1.0.26.115': 1419,
#  'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.8.0': 272,
#  'bitdiscovery': 42575,
#  'AndroidDownloadManager': 304,
#  'Camino': 112,
#  'Bloomberg|iOS|13.3.1|5.20.0|b18ca9dd5d1b86c08b1bae0c6e3774aa77ef49aa': 14,
#  'Venmo': 142,
#  'QuickTime': 26,
#  'com.seekingalpha.webwrapper': 118,
#  'YE': 216,
#  'UA-name:iOSDasherWebView; client-version: 2.60.0.2321.200501': 15940,
#  'WordPress.com; https:': 245,
#  'http.rb': 89,
#  'UA-name:iOSDasherWebView; client-version: 2.52.1.1438.200320': 14,
#  'Browser': 35,
#  'media-bot': 60,
#  'BreitbartApp': 46,
#  'Lore Document Collector 1bb1dbb613d0db2041e35f52fea672c7': 227,
#  'AppleCoreMedia': 535,
#  'Lynx': 417,
#  'Instagram 141.0.0.24.117': 5118,
#  '192.168.25.97:9092': 1330,
#  'Instagram 140.0.0.30.126 Android': 42,
#  'Nexgate Ruby Client': 226,
#  'Web App': 13,
#  'Selenium': 212,
#  'Coursera-Mobile 3.7.2': 11,
#  'Konqueror': 11,
#  'Microsoft.Data.Mashup': 11,
#  'Instagram 120.0.0.18.116': 772,
#  'Handshake iOS 2.2.5': 2078,
#  'Microsoft Office PowerPoint 2014': 192,
#  'Netsparker Agent': 111,
#  'Bloomberg|iOS|13.4.1|5.21.0|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 296,
#  'PostmanRuntime': 166,
#  'iTunes': 220,
#  'Podcasts': 95,
#  'mofang_app': 12,
#  'Bloomberg|iOS|13.3.1|5.21.0|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 35,
#  'screeenly-bot 2.0': 72,
#  'Instagram 136.0.0.22.123': 1548,
#  'Bloomberg|Android|10|5.21.0.2276979.d5d05c178|d5d05c178ce33be4d047d7aea8e2972c6f546e8d': 27,
#  'Docoloc': 22,
#  'Ephox': 11,
#  'Instagram 137.0.0.30.124': 601,
#  'Instagram 133.0.0.20.118': 1324,
#  'newsmthApp': 13,
#  'CareDroidMedications': 23,
#  'HRB-MOBILE-IOS-PHONE-TAXES-9.8.0': 57,
#  'Booking.com Android App 22.3.1': 203,
#  'fuelbot': 37,
#  'NewsSlide': 17,
#  'RiteAidMobile': 66,
#  'Coursera-Mobile 3.8.1': 193,
#  'Phantom.js bot': 464,
#  'UA-name:iOSDasherWebView; client-version: 2.62.0.2524.200508': 4049,
#  'Grailed': 34,
#  'Mobile IOS 9.2.3.1; Mozilla': 351,
#  'Booking.App': 7400,
#  '192.168.0.18': 19,
#  'NE3': 517,
#  'Instagram 142.0.0.22.109': 8401,
#  'HV Android Wrapper 0.1': 11,
#  'Screaming Frog SEO Spider': 889,
#  'UA-name:iOSDasherWebView; client-version: 2.62.20.2760.200519': 10593,
#  'UNL_SITEMASTER': 288,
#  'iMozilla': 69,
#  'Manticore 0.6.4': 52,
#  'freeweb2app': 27,
#  'Ocean': 21,
#  'Instagram 123.0.0.24.115': 230,
#  'Infowars Android': 460,
#  'Sogou web spider': 13,
#  'iPad': 354,
#  'colly - https:': 124,
#  'GeenStijlAndroidApp': 26,
#  'Handshake iOS 2.3.0': 171,
#  'SpeedaNewsPicks': 129,
#  'Watchville Android 1.5.2': 28,
#  'EPiServer LinkValidator': 14,
#  'Handshake iOS 2.3.1': 1492,
#  'WAS': 56,
#  'CastBox': 43,
#  'Instagram 143.0.0.20.122': 6349,
#  'blackboard ally - accessibility checker - http:': 34,
#  'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.9.0': 1707,
#  'lyft:android:9:6.33.3.1590119151': 1942,
#  'bma': 11,
#  'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.9.0': 779,
#  'com.tophatter v2.103.7': 3853,
#  'Instagram 132.0.0.18.129': 1036,
#  'com.tophatter v3.0.0': 16486,
#  'com.tophatter v2.103.10': 768,
#  'lyft:android:10:6.33.3.1590119151': 832,
#  'sdfsdf': 404,
#  'lyft:android:8.1.0:6.33.3.1590119151': 381,
#  'com.tophatter v2.103.5': 278,
#  'lyft:android:8.0.0:6.33.3.1590119151': 141,
#  'com.tophatter v2.103.6': 187,
#  'com.lyft.android.driver:android:9:1002.62.3.1590119153': 57,
#  'lyft:android:7.0:6.33.3.1590119151': 69,
#  '7Siters': 11,
#  'lyft:android:9:6.34.3.1590583701': 7948,
#  'Instagram 144.0.0.17.119': 4572,
#  'com.tophatter v2.101.1': 120,
#  'curb': 14,
#  'broken-link-checker': 12,
#  'spyglassbot puppeteer': 52,
#  'UA-name:iOSDasherWebView; client-version: 2.64.0.2878.200522': 3545,
#  'UA-name:iOSDasherWebView; client-version: 2.68.0.3047.200529': 20777,
#  'Microsoft Office PowerPoint 2013': 15,
#  'lyft:android:10:6.34.3.1590583701': 4895,
#  'Bloomberg|iOS|13.4.1|5.22.1|9711b09eb675cf0e3556545cbd97f1441e374cf6': 13,
#  'com.tophatter v2.100.0': 33,
#  'com.tophatter v4.0.1': 520,
#  'lyft:android:8.1.0:6.34.3.1590583701': 1759,
#  'win10chrome76': 13,
#  'lyft:android:8.0.0:6.34.3.1590583701': 919,
#  'PipelinePilot': 11,
#  'lyft:android:7.0:6.34.3.1590583701': 640,
#  'com.tophatter v4.0.3': 194,
#  'eXtyles WinINet 1.0': 17,
#  'Handshake iOS 2.3.2': 933,
#  'Citoid': 13,
#  'com.lyft.android.driver:android:10:1002.63.3.1590584246': 262,
#  'Opendi Screenshot Bot bot@opendi.com': 135110,
#  'com.lyft.android.driver:android:9:1002.63.3.1590584246': 300,
#  'lyft:android:7.1.1:6.34.3.1590583701': 224,
#  'lyft:android:9:6.35.3.1591222463': 8583,
#  'Instagram 145.0.0.17.119': 4274,
#  'lyft:android:6.0.1:6.34.3.1590583701': 166,
#  'com.lyft.android.driver:android:8.1.0:1002.63.3.1590584246': 54,
#  'lyft:android:10:6.35.3.1591222463': 6391,
#  'com.lyft.android.driver:android:8.0.0:1002.63.3.1590584246': 37,
#  'lyft:android:7.1.2:6.34.3.1590583701': 37,
#  'com.lyft.android.driver:android:9:1002.64.3.1591188541': 405,
#  'com.lyft.android.driver:android:7.0:1002.63.3.1590584246': 16,
#  'Bloomberg|iOS|13.4.1|5.23.0|d63663da08e3ad75571d9550d5fd685884e03392': 41,
#  'lyft:android:8.1.0:6.35.3.1591222463': 1858,
#  'com.tophatter v4.0.4': 225,
#  'WebKit': 12,
#  'com.lyft.android.driver:android:10:1002.62.3.1590119153': 12,
#  'com.lyft.android.driver:android:10:1002.64.3.1591188541': 399,
#  'lyft:android:8.0.0:6.35.3.1591222463': 1173,
#  'lyft:android:7.0:6.35.3.1591222463': 780,
#  'integrity': 26,
#  'lyft:android:6.0.1:6.35.3.1591222463': 176,
#  'UA-name:iOSDasherWebView; client-version: 2.70.1.3286.200610': 928,
#  'lyft:android:7.1.1:6.35.3.1591222463': 251,
#  'HRB-MOBILE-IOS-PHONE-TAXES-9.9.0': 347,
#  'UA-name:iOSDasherWebView; client-version: 2.70.2.3352.200612': 17426,
#  'Papers2 Thumbnail Helper': 41,
#  'Downcast': 13,
#  'liloiosapp-66.1.6 Mozilla': 37,
#  'com.lyft.android.driver:android:8.0.0:1002.64.3.1591188541': 11,
#  'lyft:android:7.1.2:6.35.3.1591222463': 22,
#  'Instagram 115.1.0.71.189': 1030,
#  'hogehoge': 126,
#  'Turnitin': 7143,
#  'CourierAndroid 5.22.2 rv:434': 12,
#  'Rustbot': 314,
#  'Drupal': 13,
#  'newspaper': 81,
#  'lyft:android:9:6.36.3.1591794132': 6780,
#  'Instagram 145.0.0.32.119 Android': 27,
#  'lyft:android:10:6.36.3.1591794132': 5638,
#  'com.lyft.android.driver:android:8.1.0:1002.64.3.1591188541': 11,
#  'UA-name:iOSDasherWebView; client-version: 2.72.0.3380.200612': 22309,
#  'Handshake iOS 2.3.3': 1193,
#  'lyft:android:8.1.0:6.36.3.1591794132': 1314,
#  'Yewno-Open': 17,
#  'lyft:android:7.0:6.36.3.1591794132': 568,
#  'lyft:android:8.0.0:6.36.3.1591794132': 1004,
#  'SalesforceMobileSDK': 18,
#  'com.lyft.android.driver:android:9:1002.65.3.1591791298': 289,
#  'com.lyft.android.driver:android:10:1002.65.3.1591791298': 321,
#  'lyft:android:7.1.1:6.36.3.1591794132': 190,
#  'Kronos': 11,
#  'lyft:android:6.0.1:6.36.3.1591794132': 143,
#  'Instagram 146.0.0.21.122': 6656,
#  'Instagram 124.0.0.11.473': 39,
#  'Party City Mobile App; iOS iPhone; 13.5.1; 6.1.16.0 : 48;': 11,
#  'EcoSearch': 18,
#  'PollEvPresenter': 40,
#  'com.lyft.android.driver:android:8.0.0:1002.65.3.1591791298': 22,
#  'Accessibility scan - NLM staff': 15945,
#  'Coursera-Mobile 3.9.1': 99,
#  'lyft:android:9:6.37.3.1592395944': 5405,
#  'Instagram 139.0.0.34.120': 528,
#  'ds9 2.004.1': 14,
#  'lyft:android:10:6.37.3.1592395944': 4794,
#  'UA-name:iOSDasherWebView; client-version: 2.74.0.1': 21891,
#  'Handshake iOS 2.3.4': 1898,
#  'lyft:android:8.1.0:6.37.3.1592395944': 1028,
#  'lyft:android:8.0.0:6.37.3.1592395944': 775,
#  'SearchBlox': 42,
#  'Asana': 93,
#  'lyft:android:7.0:6.37.3.1592395944': 470,
#  'com.lyft.android.driver:android:9:1002.66.3.1592396259': 240,
#  'com.lyft.android.driver:android:10:1002.66.3.1592396259': 253,
#  'Instagram 147.0.0.30.121': 5256,
#  'lyft:android:7.1.1:6.37.3.1592395944': 142,
#  'lyft:android:6.0.1:6.37.3.1592395944': 90,
#  'RANDOM': 47,
#  'TotalValidator': 31,
#  'Instagram 147.0.0.42.124 Android': 82,
#  'edbrowse': 240,
#  'ADPTablet': 361,
#  'lyft:android:9:6.38.3.1593001991': 8503,
#  'lyft:android:10:6.38.3.1593001991': 8559,
#  'UA-name:iOSDasherWebView; client-version: 2.76.0.3489.200626': 27191,
#  'lyft:android:8.1.0:6.38.3.1593001991': 1661,
#  'Bloomberg|iOS|13.5.1|5.24.0|b954812d89433af9535e6ab38f9141628dc46e27': 86,
#  'lyft:android:8.0.0:6.38.3.1593001991': 1476,
#  'VSE': 12,
#  'Java': 100,
#  'lyft:android:7.0:6.38.3.1593001991': 773,
#  'lyft:android:6.0.1:6.38.3.1593001991': 153,
#  'lyft:android:7.1.1:6.38.3.1593001991': 280,
#  'Instagram 148.0.0.26.120': 14011,
#  'com.lyft.android.driver:android:10:1002.67.3.1593002387': 340,
#  'com.lyft.android.driver:android:9:1002.67.3.1593002387': 256,
#  'GreenChoiceNow': 11,
#  'Connie': 23,
#  'axios': 20,
#  'JovemNerdApp': 741,
#  'Bloomberg|iOS|13.5.1|5.25.0|688ee79ba47d67452eae5db8faede63e8ee6801d': 484,
#  'Bloomberg|Android|10|5.25.0.2358368.688ee79ba|688ee79ba47d67452eae5db8faede63e8ee6801d': 68,
#  'UA-name:iOSDasherWebView; client-version: 2.78.0.3587.200702': 31604,
#  'QZONEJSSDK': 27,
#  'HRB-MOBILE-IOS-TABLET-TAXES-TOUCHID-9.9.0': 218,
#  'Android ExpediaBookings': 14,
#  'Autn-WKOOP': 250,
#  'com.tophatter v5.0.1': 504,
#  'PodcastAddict': 11,
#  'desktop': 1040,
#  'Turo': 14,
#  'CBC': 664,
#  'cnn-mobile-app': 2542,
#  'HRB-MOBILE-IOS-TABLET-TAXES-9.9.0': 71,
#  'Instagram 131.0.0.21.117': 161,
#  'lyft:android:9:6.40.3.1594331922': 2906,
#  'lyft:android:10:6.40.3.1594331922': 3741,
#  'UA-name:iOSDasherWebView; client-version: 2.80.0.3681.200710': 9319,
#  'Lync': 35,
#  'lyft:android:8.1.0:6.40.3.1594331922': 586,
#  'lyft:android:8.0.0:6.40.3.1594331922': 578,
#  'HRB-MOBILE-IOS-TABLET-TAXES-FACEID-9.9.0': 26,
#  'HRB-MOBILE-IOS-PHONE-TAXES-TOUCHID-9.9.0-Mozilla': 25,
#  'lyft:android:7.0:6.40.3.1594331922': 302,
#  '{user_agent}': 59,
#  'lyft:android:7.1.1:6.40.3.1594331922': 86,
#  'AtlassianMobileApp': 16,
#  'com.automizely.shopping': 16,
#  'com.lyft.android.driver:android:10:1002.69.3.1594209951': 142,
#  'com.lyft.android.driver:android:9:1002.69.3.1594209951': 47,
#  'lyft:android:6.0.1:6.40.3.1594331922': 71,
#  'HRB-MOBILE-IOS-PHONE-TAXES-FACEID-9.10.0': 41,
#  'UA-name:iOSDasherWebView; client-version: 2.80.1.3740.200716': 11287,
#  'Instagram 150.0.0.22.119': 3977,
#  'AfricaWeb: GhanaWeb': 19,
#  'SCMGUARD': 26,
#  'Parler': 24,
#  'WayfairApp': 27,
#  'Bloomberg|iOS|13.5.1|5.26.0|0d2c9fc30a7d66305ef5ac5cbebf7cd19474e0b5': 92,
#  'lyft:android:9:6.41.3.1594814997': 1612,
#  'Handshake iOS 3.0.0': 339,
#  'lyft:android:10:6.41.3.1594814997': 2208,
#  'UA-name:iOSDasherWebView; client-version: 2.82.0.3756.200717': 10869,
#  'http4s-blaze': 21,
#  'lyft:android:8.0.0:6.41.3.1594814997': 256,
#  'lyft:android:8.1.0:6.41.3.1594814997': 232,
#  'Bloomberg|Android|10|5.26.0.2377502.0d2c9fc30|0d2c9fc30a7d66305ef5ac5cbebf7cd19474e0b5': 11,
#  'lyft:android:7.0:6.41.3.1594814997': 128,
#  'Instagram 129.0.0.19.117': 568,
#  'com.lyft.android.driver:android:10:1002.70.3.1595041156': 62,
#  'ShortLinkTranslate': 19,
#  'lyft:android:7.1.1:6.41.3.1594814997': 46,
#  'netdisk;2.2.2;pc;pc-mac;10.14.5;macbaiduyunguanjia': 13,
#  'lyft:android:6.0.1:6.41.3.1594814997': 23,
#  'com.lyft.android.driver:android:9:1002.70.3.1595041156': 13,
#  'Revolut': 22,
#  'browser1': 17}

# %%
# Method 1
samp = pd.DataFrame()
for browser, visits in brows.items():
    samp = pd.concat([samp,pd.DataFrame([[browser,visits]], columns=['Browser','No. of visits'])])
samp = samp.set_index('Browser')
samp
# Out:
#                                                     No. of visits
# Browser
# Chrome                                                 2310647276
# Safari                                                 1694664472
# Edge                                                    199346714
# Internet Explorer                                       180553037
# Firefox                                                 159121768
# ...                                                           ...
# netdisk;2.2.2;pc;pc-mac;10.14.5;macbaiduyunguanjia             13
# lyft:android:6.0.1:6.41.3.1594814997                           23
# com.lyft.android.driver:android:9:1002.70.3.159...             13
# Revolut                                                        22
# browser1                                                       17
#
# [414 rows x 1 columns]

# %%
# Method 2
df_browser = pd.DataFrame(brows, index=['visits']).reset_index()
df_browser.melt(id_vars='index',  var_name='Browser', value_name='No. of visits').drop(columns='index').set_index('Browser')
# Out:
#                                                     No. of visits
# Browser
# Chrome                                                 2310647276
# Safari                                                 1694664472
# Edge                                                    199346714
# Internet Explorer                                       180553037
# Firefox                                                 159121768
# ...                                                           ...
# netdisk;2.2.2;pc;pc-mac;10.14.5;macbaiduyunguanjia             13
# lyft:android:6.0.1:6.41.3.1594814997                           23
# com.lyft.android.driver:android:9:1002.70.3.159...             13
# Revolut                                                        22
# browser1                                                       17
#
# [414 rows x 1 columns]

# %% [markdown]
# ____

# %% [markdown]
# ## 4. Retrieving data of your choice from Data.gov

# %%
samp['No. of visits'].agg(sum)
# Out:
# 4836478291

# %%
data2['totals']['visits']
# Out:
# 4836478291
